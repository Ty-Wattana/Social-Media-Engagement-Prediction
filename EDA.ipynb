# %%
import pandas as pd
import numpy as np
from langdetect import detect
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('twitter_data(all).csv')
df
# Out:
#                       Date                   ID       Name  \
# 0      2021-03-22 10:46:46  1373949268164153345    YouTube
# 1      2021-03-22 10:46:32  1373949209187995652    YouTube
# 2      2021-03-22 10:46:05  1373949093886582784    YouTube
# 3      2021-03-22 06:00:04  1373877114743705602    YouTube
# 4      2021-03-21 19:38:33  1373720706689638401    YouTube
# ...                    ...                  ...        ...
# 16081  2020-05-01 03:02:37  1256056403715735554  Gal Gadot
# 16082  2020-05-01 02:32:38  1256048857625976834  Gal Gadot
# 16083  2020-05-01 02:31:38  1256048604088688640  Gal Gadot
# 16084  2020-04-22 22:30:54  1253088919354134528  Gal Gadot
# 16085  2020-04-21 19:27:09  1252680291476520961  Gal Gadot
#
#                                                     Text  Hashtags  \
# 0                         @StarlightWarm and beautiful 🌹       NaN
# 1            @TheeAngryWalnut Spreading love everywhere!       NaN
# ...

# %%
df[df['Name'] == 'Coca-Cola']
# Out:
#                     Date                   ID       Name  \
# 4800 2021-03-21 23:16:06  1373775456361664520  Coca-Cola
# 4801 2021-03-21 22:30:28  1373763971271028741  Coca-Cola
# 4802 2021-03-21 22:27:44  1373763280758509573  Coca-Cola
# 4803 2021-03-21 19:46:19  1373722660622991363  Coca-Cola
# 4804 2021-03-20 21:50:27  1373391513959415808  Coca-Cola
# ...                  ...                  ...        ...
# 4995 2021-02-26 18:56:55  1365375307809701894  Coca-Cola
# 4996 2021-02-26 15:28:20  1365322816275570698  Coca-Cola
# 4997 2021-02-26 15:14:33  1365319346361409543  Coca-Cola
# 4998 2021-02-26 14:34:24  1365309245072281601  Coca-Cola
# 4999 2021-02-25 22:05:10  1365060294968500225  Coca-Cola
#
#                                                    Text Hashtags  \
# 4800  @Angelina_blondi Hi there Angelina! Unfortunat...      NaN
# 4801  @adedokun_idris Hi, please send us a private m...      NaN
# 4802  @doximoma Hi! Thanks for being a passionate fl...      NaN
# ...

# %%
df[(df['Favorite count'] > 10) & (df['Retweet count'] > 10)]
# Out:
#                      Date                   ID       Name  \
# 3     2021-03-22 06:00:04  1373877114743705602    YouTube
# 19    2021-03-21 13:55:36  1373634398919262210    YouTube
# 23    2021-03-21 11:00:01  1373590213818212352    YouTube
# 24    2021-03-20 23:54:48  1373422805199458305    YouTube
# 33    2021-03-20 20:00:00  1373363718151667712    YouTube
# ...                   ...                  ...        ...
# 16081 2020-05-01 03:02:37  1256056403715735554  Gal Gadot
# 16082 2020-05-01 02:32:38  1256048857625976834  Gal Gadot
# 16083 2020-05-01 02:31:38  1256048604088688640  Gal Gadot
# 16084 2020-04-22 22:30:54  1253088919354134528  Gal Gadot
# 16085 2020-04-21 19:27:09  1252680291476520961  Gal Gadot
#
#                                                     Text        Hashtags  \
# 3      💞 The adventures of Natsumi and Haru! These si...             NaN
# 19                   @MKBHD 10/10, would sign up again 🏆             NaN
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['ID'] = df['ID'].astype(str)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16086 entries, 0 to 16085
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            16086 non-null  datetime64[ns]
#  1   ID              16086 non-null  object
#  2   Name            16086 non-null  object
#  3   Text            16086 non-null  object
#  4   Hashtags        3474 non-null   object
#  5   User Mentions   8378 non-null   object
#  6   Symbols         15 non-null     object
#  7   Media           2643 non-null   object
#  8   Source          16086 non-null  object
#  9   Location        11390 non-null  object
#  10  Follower count  16086 non-null  float64
#  11  Friends count   16086 non-null  float64
#  12  Favorite count  16086 non-null  float64
#  13  Retweet count   16086 non-null  float64
#  14  Status count    16086 non-null  float64
#  15  Industries      16086 non-null  object
# ...

# %%
df.describe()
# Out:
#        Follower count  Friends count  Favorite count  Retweet count  \
# count    1.608600e+04   16086.000000    1.608600e+04   16086.000000
# mean     2.625512e+07   44383.983153    1.633684e+04    2667.382942
# std      3.150023e+07  114382.423665    8.129718e+04   15892.287640
# min      2.900000e+01       0.000000    0.000000e+00       0.000000
# 25%      2.294552e+06     169.000000    1.000000e+00       0.000000
# 50%      1.119321e+07     735.000000    4.200000e+01      33.000000
# 75%      4.102695e+07   26835.000000    2.025000e+03     609.000000
# max      1.300607e+08  593779.000000    4.212155e+06  810444.000000
#
#         Status count
# count   16086.000000
# mean   107971.507584
# std    151083.601401
# min         2.000000
# 25%     12576.000000
# 50%     36113.000000
# 75%    137296.000000
# max    714689.000000

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FEEA2EEFA0>,
# ...
#       dtype=object)

# %%
df['Follower count'].plot.hist()

# %%
df['Favorite count'].plot.hist()

# %%
df['Friends count'].plot.hist()

# %%
df['Retweet count'].plot.hist()

# %%
df['Status count'].plot.hist()

# %%
df['Industries'].value_counts().plot.bar()

# %%
df['Location'].value_counts()[:5].plot.pie()

# %%
df.boxplot(column=['Follower count','Friends count', 'Favorite count','Retweet count', 'Status count'])

# %%
df.boxplot(column=['Friends count', 'Status count'])

# %%
df.boxplot(column=['Favorite count','Retweet count'])

# %%
pd.pivot_table(df, values='Retweet count', index=['Location'],columns=['Industries'], aggfunc=np.sum)
# Out:
# Industries                     Actor  Influencer      News  Non-tech Company  \
# Location
# Around the world                 NaN         NaN    6383.0               NaN
# Atlanta, GA                      NaN         NaN       NaN             839.0
# Austin, TX                       NaN         NaN       NaN              89.0
# Beaverton, OR                    NaN         NaN       NaN             309.0
# Bloomington, Indiana             NaN       279.0       NaN               NaN
# Boston, MA                       NaN     45266.0       NaN               NaN
# California                   89437.0         NaN       NaN               NaN
# California, USA                  NaN         NaN       NaN               NaN
# Charleston, SC                   NaN       426.0       NaN               NaN
# Cleveland, OH                    NaN       936.0       NaN               NaN
# DALLAS/LA                        NaN         NaN       NaN               NaN
# ...

# %%
pd.pivot_table(df, values='Retweet count', index=['Source'],columns=['Industries'], aggfunc=np.sum)
# Out:
# Industries                            Actor  Influencer      News  \
# Source
# AgoraPulse Manager                      NaN      2347.0       NaN
# ArtPal                                  NaN         9.0       NaN
# Buffer                                  NaN       115.0       NaN
# Canva                                   NaN         2.0       NaN
# CoSchedule                              NaN        64.0       NaN
# Commun.it Intelligence                  NaN        22.0       NaN
# Conversocial                            NaN         NaN       NaN
# Dash Hudson                             NaN         NaN       NaN
# Hootsuite                             678.0         NaN       NaN
# Hootsuite Inc.                          NaN       238.0       NaN
# IFTTT                                   NaN         0.0       NaN
# Instagram                            8027.0         7.0       NaN
# Khoros Publishing                       NaN         NaN       NaN
# ...

# %%
df.plot.scatter(x='Follower count' ,y='Retweet count')

# %%
df.plot.scatter(x='Follower count' ,y='Favorite count')

# %%
df['Date'].dt.hour.hist()

# %%
df['Date'].dt.dayofweek.hist()

# %%
df.corr()
# Out:
#                 Follower count  Friends count  Favorite count  Retweet count  \
# Follower count        1.000000       0.205093        0.256748       0.181928
# Friends count         0.205093       1.000000        0.075980       0.041496
# Favorite count        0.256748       0.075980        1.000000       0.616857
# Retweet count         0.181928       0.041496        0.616857       1.000000
# Status count         -0.236938       0.131381       -0.122805      -0.101263
#
#                 Status count
# Follower count     -0.236938
# Friends count       0.131381
# Favorite count     -0.122805
# Retweet count      -0.101263
# Status count        1.000000

# %%
sns.heatmap(df.corr(), xticklabels=df.corr().columns, yticklabels=df.corr().columns)
